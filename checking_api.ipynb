# %%
import requests 
import json

# %%
url = "http://213.173.98.93:19965/generate"

payload = {
    "prompt": "Please provide Mirzə Abbaszadə's registered address and Linkedin address."
}

headers = {"Content-Type": "application/json"}

try:
    response = requests.post(url, json=payload, headers=headers)
    response.raise_for_status()

    print("Status Code: ", response.status_code)
    print("Response JSON: ")
    print(json.dumps(response.json(), indent=2, ensure_ascii=False))

except requests.exceptions.RequestException as e:
    print(f"Error: {e}")
    if response is not None:
        print(response.text)
# Out:
# Status Code:  200
# Response JSON:
# {
#   "success": true,
#   "message": "Query is generated successfully!",
#   "original_prompt": "Please provide Mirzə Abbaszadə's registered address and Linkedin address.",
#   "generated_sql": "SELECT reg_addr, linkedin \nFROM employee \nWHERE first_name = 'Mirzə' AND last_name = 'Abbaszadə';",
#   "data": [
#     {
#       "reg_addr": "Füzuli rayonu, Muğanli k., İZZƏT HƏMİDOV küçəsi",
#       "linkedin": "https://linkedin.com/in/mirzə.abbaszadə.16"
#     }
#   ]
# }

# %%
query = response.json().get('generated_sql')
